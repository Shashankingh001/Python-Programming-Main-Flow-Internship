# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\Gaurvi\\Downloads\\ipl_data.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info  #concise summary
# Out:
# <bound method DataFrame.info of        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# ...

# %%
data.describe() #descriptive statistics
# Out:
#                 mid          runs       wickets         overs   runs_last_5  \
# count  76014.000000  76014.000000  76014.000000  76014.000000  76014.000000
# mean     308.627740     74.889349      2.415844      9.783068     33.216434
# std      178.156878     48.823327      2.015207      5.772587     14.914174
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%      154.000000     34.000000      1.000000      4.600000     24.000000
# 50%      308.000000     70.000000      2.000000      9.600000     34.000000
# 75%      463.000000    111.000000      4.000000     14.600000     43.000000
# max      617.000000    263.000000     10.000000     19.600000    113.000000
#
#        wickets_last_5       striker   non-striker         total
# count    76014.000000  76014.000000  76014.000000  76014.000000
# mean         1.120307     24.962283      8.869287    160.901452
# std          1.053343     20.079752     10.795742     29.246231
# ...

# %%
data = data.drop_duplicates()
data
# Out:
#        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# ...

# %%
data.isnull()
# Out:
#          mid   date  venue  bat_team  bowl_team  batsman  bowler   runs  \
# 0      False  False  False     False      False    False   False  False
# 1      False  False  False     False      False    False   False  False
# 2      False  False  False     False      False    False   False  False
# 3      False  False  False     False      False    False   False  False
# 4      False  False  False     False      False    False   False  False
# ...      ...    ...    ...       ...        ...      ...     ...    ...
# 76009  False  False  False     False      False    False   False  False
# 76010  False  False  False     False      False    False   False  False
# 76011  False  False  False     False      False    False   False  False
# 76012  False  False  False     False      False    False   False  False
# 76013  False  False  False     False      False    False   False  False
#
#        wickets  overs  runs_last_5  wickets_last_5  striker  non-striker  \
# ...

# %%
data.isnull().sum()
# Out:
# mid               0
# date              0
# venue             0
# bat_team          0
# bowl_team         0
# batsman           0
# bowler            0
# runs              0
# wickets           0
# overs             0
# runs_last_5       0
# wickets_last_5    0
# striker           0
# non-striker       0
# total             0
# dtype: int64

# %%
data.notnull()
# Out:
#         mid  date  venue  bat_team  bowl_team  batsman  bowler  runs  wickets  \
# 0      True  True   True      True       True     True    True  True     True
# 1      True  True   True      True       True     True    True  True     True
# 2      True  True   True      True       True     True    True  True     True
# 3      True  True   True      True       True     True    True  True     True
# 4      True  True   True      True       True     True    True  True     True
# ...     ...   ...    ...       ...        ...      ...     ...   ...      ...
# 76009  True  True   True      True       True     True    True  True     True
# 76010  True  True   True      True       True     True    True  True     True
# 76011  True  True   True      True       True     True    True  True     True
# 76012  True  True   True      True       True     True    True  True     True
# 76013  True  True   True      True       True     True    True  True     True
#
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
import numpy as np
from scipy import stats

# %%
#detect the outliers using IQR
data.columns
# Out:
# Index(['mid', 'date', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
#        'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
data.drop(['mid'], axis=1, inplace=True)
data.columns
# Out:
# Index(['date', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler', 'runs',
#        'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
Q1= data.quantile(0.25)
Q3= data.quantile(0.75)
IQR= Q3-Q1
print(IQR)
# Out:
# runs              77.0
# wickets            3.0
# overs             10.0
# runs_last_5       19.0
# wickets_last_5     2.0
# striker           25.0
# non-striker       12.0
# total             39.0
# dtype: float64

# %%
data=data[~((data<(Q1-1.5*IQR))|(data2>(Q3+1.5*IQR))).any(axis=1)]
data
# Out:
# C:\Users\Gaurvi\AppData\Local\Temp\ipykernel_1732\3058057288.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data=data[~((data<(Q1-1.5*IQR))|(data2>(Q3+1.5*IQR))).any(axis=1)]
#              date                                      venue  \
# 0      2008-04-18                      M Chinnaswamy Stadium
# 1      2008-04-18                      M Chinnaswamy Stadium
# 2      2008-04-18                      M Chinnaswamy Stadium
# 3      2008-04-18                      M Chinnaswamy Stadium
# 4      2008-04-18                      M Chinnaswamy Stadium
# ...           ...                                        ...
# 76009  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# ...

# %%
data.describe()
# Out:
#                runs       wickets         overs   runs_last_5  wickets_last_5  \
# count  69204.000000  69204.000000  69204.000000  69204.000000    69204.000000
# mean      70.414138      2.403430      9.387439     31.757312        1.150150
# std       46.659197      1.971011      5.736384     13.935035        1.022165
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%       32.000000      1.000000      4.400000     24.000000        0.000000
# 50%       65.000000      2.000000      9.200000     33.000000        1.000000
# 75%      104.000000      4.000000     14.300000     41.000000        2.000000
# max      226.000000      8.000000     19.600000     71.000000        5.000000
#
#             striker   non-striker         total
# count  69204.000000  69204.000000  69204.000000
# mean      22.032296      7.126423    159.362017
# std       15.940319      7.503109     26.425670
# min        0.000000      0.000000     92.000000
# ...
